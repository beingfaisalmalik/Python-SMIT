# %% [markdown]
# # Python Day 3

# %% [markdown]
# ### Text formatting / formation/concatination

# %%
# no space beacuse of the separator

# %% [markdown]
# # Rules For Python Variables :
#
# * A variable name must start with a letter or the underscore character
# * A variable name cannot start with a number
# * A variable name can only contain alpha-numeric characters and underscores (A-z, 0-9, and _ )
# * Variable names are case-sensitive (age, Age and AGE are three different variables)
# * A variable name cannot be any of the Python keywords.

# %%
student_name = 'Muhammad Faisal'
print(student_name)
# Out:
# Muhammad Faisal

# %%
# Return and non Return
# isky answer ko varible mai dal sken it is returnin some variable
a = len("Faisal")
print(a)
# Out:
# 6

# %%
# Non Return fucntion
b = print('Faisal')
print(b)
print(b)
# Out:
# Faisal
# None
# None

# %%
"""
Saylani Mass IT
Muhammad Faisal

"""
# Out:
# '\nSaylani Mass IT\nMuhammad Faisal\n\n'

# %% [markdown]
# # Concatination
# ## Using The F Method

# %%
# Using The F Method
first_name = "Muhammad Faisal"
last_name = "Malik "
institute_name = "Saylani Mass IT Training"
age = 23
card = f"Name: {first_name} {last_name} \nInstitute Name : {institute_name} \nAge: {age}"
print(card)
# Out:
# Name: Muhammad Faisal Malik
# Institute Name : Saylani Mass IT Training
# Age: 23

# %% [markdown]
# ## Traditional Plus (+) Method

# %%
#Traditional Method with string only
card = "Name: "+ first_name +"\nInstitute Name :"+institute_name
print(card)
# Out:
# Name: Muhammad Faisal
# Institute Name :Saylani Mass IT Training

# %%
# Traditional Method with The Error Of Int
#Traditional Method with string only
card = "Name: "+ first_name +"\nInstitute Name :"+institute_name+ "\nAge: "+age
print(card)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4884\1664187836.py in <module>
#       1 # Traditional Method with The Error Of Int
#       2 #Traditional Method with string only
# ----> 3 card = "Name: "+ first_name +"\nInstitute Name :"+institute_name+ "\nAge: "+age
#       4 print(card)
#
# TypeError: can only concatenate str (not "int") to str

# %%
# Traditional Method with The TypeCasting Of Int
#Traditional Method with string only
card = "Name: "+ first_name +"\nInstitute Name :"+institute_name+ "\nAge: "+str(age)
print(card)
# Out:
# Name: Muhammad Faisal
# Institute Name :Saylani Mass IT Training
# Age: 23

# %% [markdown]
# ## The Format Method

# %%
# The Format Method
Card2 = """
Institute Name :{}
Name :  {} {}
Age : {}

""".format(institute_name,first_name,last_name,age)
print(Card2)
# Out:
# Institute Name :Saylani Mass IT Training
# Name :  Muhammad Faisal Malik
# Age : 23

# %%
# The Format Method Without Sequence
# The Format Method
Card2 = """
Institute Name :{3}
Name :  {2} {1}
Age : {0}

""".format(institute_name,first_name,last_name,age)
print(Card2)
# Out:
# Institute Name :23
# Name :  Malik  Muhammad Faisal
# Age : Saylani Mass IT Training

# %% [markdown]
# # With F

# %%
# The F Method By Sir
Card2 = f"""
Institute Name :{institute_name}
Name :  {first_name} {last_name}
Age : {age}

"""
print(Card2)
# Out:
# Institute Name :Saylani Mass IT Training
# Name :  Muhammad Faisal Malik
# Age : 23

# %% [markdown]
# # The % Method

# %%
Card2 = """
Institute Name :%s
Name :  %s %s
Age : %d

"""%(institute_name,first_name,last_name,age)
print(Card2)
# Out:
# Institute Name :Saylani Mass IT Training
# Name :  Muhammad Faisal Malik
# Age : 23

# %%
# for seeing method attribute
#That changes it is inline 
# That changes The Memory Is 
j=0
method = dir(Card2)
for i in method:
    if "_" not in i:
        print(" ")
        print(j,i)
        j = j+1
# Out:
#
# 0 capitalize
#
# 1 casefold
#
# 2 center
#
# 3 count
#
# 4 encode
#
# 5 endswith
#
# 6 expandtabs
#
# 7 find
#
# 8 format
#
# 9 index
#
# 10 isalnum
#
# 11 isalpha
#
# 12 isascii
#
# 13 isdecimal
#
# 14 isdigit
#
# 15 isidentifier
#
# 16 islower
#
# 17 isnumeric
#
# 18 isprintable
#
# 19 isspace
#
# 20 istitle
#
# 21 isupper
#
# 22 join
#
# 23 ljust
#
# 24 lower
#
# 25 lstrip
#
# 26 maketrans
#
# 27 partition
#
# 28 removeprefix
#
# 29 removesuffix
#
# 30 replace
#
# 31 rfind
#
# 32 rindex
#
# 33 rjust
#
# 34 rpartition
#
# 35 rsplit
#
# 36 rstrip
#
# 37 split
#
# 38 splitlines
#
# 39 startswith
#
# 40 strip
#
# 41 swapcase
#
# 42 title
#
# 43 translate
#
# 44 upper
#
# 45 zfill

# %%
print(Card2.isdigit())
#How Many Times Name Is Written
print(Card2.count("Name"))
print(Card2.upper())
#Chain Rule
print(Card2.casefold().count('FAISAL'))
print(first_name.encode(encoding="ascii"))
# Out:
# False
# 2
#
# INSTITUTE NAME :SAYLANI MASS IT TRAINING
# NAME :  MUHAMMAD FAISAL MALIK
# AGE : 23
#
#
# 0
# b'Muhammad Faisal'

# %% [markdown]
# # Home Work
# #### Apply 45 String Metods On Card Method

# %%
# Using The F Method
first_name = "Muhammad Faisal"
last_name = "Malik "
institute_name = "Saylani Mass IT Training"
age = 23
Card2 = f"Name: {first_name} {last_name} \nInstitute Name : {institute_name} \nAge: {age}"
print(Card2)
print(" ")
X0 = Card2.capitalize()
 
print('Using The capitalize Method')
 
print(X0)
print(" ")
X1 = Card2.casefold()
 
print('Using The casefold Method')
 
print(X1)
print(" ")
X2 = Card2.center(10)
 
print('Using The center Method')
 
print(X2)
print(" ")
X3 = Card2.count('Faisal')
 
print('Using The count Method')
 
print(X3)
print(" ")
X4 = Card2.encode()
 
print('Using The encode Method')
 
print(X4)
print(" ")
X5 = Card2.endswith("Faisal")
 
print('Using The endswith Method')
 
print(X5)
print(" ")
X6 = Card2.expandtabs()
 
print('Using The expandtabs Method')
 
print(X6)
print(" ") 
X7 = Card2.find("Faisal")
 
print('Using The find Method')
 
print(X7)
print(" ")
X8 = Card2.format()
 
print('Using The format Method')
 
print(X8)
print(" ")
X9 = Card2.index("Faisal")
 
print('Using The index Method')
 
print(X9)
print(" ")
X10 = Card2.isalnum()
 
print('Using The isalnum Method')
 
print(X10)
print(" ")
X11 = Card2.isalpha()
 
print('Using The isalpha Method')
 
print(X11)
print(" ")
X12 = Card2.isascii()
 
print('Using The isascii Method')
 
print(X12)
print(" ")
X13 = Card2.isdecimal()
 
print('Using The isdecimal Method')
 
print(X13)
print(" ")
X14 = Card2.isdigit()
 
print('Using The isdigit Method')
 
print(X14)
print(" ")
X15 = Card2.isidentifier()
 
print('Using The isidentifier Method')
 
print(X15)
print(" ")
X16 = Card2.islower()
 
print('Using The islower Method')
 
print(X16)
print(" ")
X17 = Card2.isnumeric()
 
print('Using The isnumeric Method')
 
print(X17)
print(" ") 
X18 = Card2.isprintable()
 
print('Using The isprintable Method')
 
print(X18)
print(" ") 
X19 = Card2.isspace()
 
print('Using The isspace Method')
 
print(X19)
 
X20 = Card2.istitle()
 
print('Using The istitle Method')
 
print(X20)
print(" ")
X21 = Card2.isupper()
 
print('Using The isupper Method')
 
print(X21)
print(" ")
X22 = Card2.join("#")
 
print('Using The join Method')
 
print(X22)
print(" ")
X23 = Card2.ljust(5)
 
print('Using The ljust Method')
 
print(X23)
print(" ")
X24 = Card2.lower()
 
print('Using The lower Method')
 
print(X24)
print(" ")
X25 = Card2.lstrip()
 
print('Using The lstrip Method')
 
print(X25)
print(" ")
 
X26 = Card2.maketrans("S", "P")
 
print('Using The maketrans Method')
 
print(X26)
print(" ")
X27 = Card2.partition("Faisal")
 
print('Using The partition Method')
 
print(X27)
print(" ")
X28 = Card2.removeprefix("Fai")
 
print('Using The removeprefix Method')
 
print(X28)
print(" ")
X29 = Card2.removesuffix("Fai")
 
print('Using The removesuffix Method')
 
print(X29)
print(" ") 
X30 = Card2.replace("Faisal","Ali")
 
print('Using The replace Method')
 
print(X30)
print(" ") 
X31 = Card2.rfind("Faisal")
 
print('Using The rfind Method')
 
print(X31)
print(" ")
X32 = Card2.rindex("Faisal")
 
print('Using The rindex Method')
 
print(X32)
print(" ")
X33 = Card2.rjust(20)
 
print('Using The rjust Method')
 
print(X33)
print(" ")
X34 = Card2.rpartition("Faisal")
 
print('Using The rpartition Method')
 
print(X34)
print(" ") 
X35 = Card2.rsplit()
 
print('Using The rsplit Method')
 
print(X35)
print(" ")
X36 = Card2.rstrip()
 
print('Using The rstrip Method')
 
print(X36)
print(" ")
X37 = Card2.split(" ")

print('Using The split Method')
 
print(X37)
print(" ")
X38 = Card2.splitlines(10)
 
print('Using The splitlines Method')
 
print(X38)
print(" ")
X39 = Card2.startswith("Name")
 
print('Using The startswith Method')
 
print(X39)
print(" ")
X40 = Card2.strip()
 
print('Using The strip Method')
 
print(X40)
print(" ")
X41 = Card2.swapcase()
 
print('Using The swapcase Method')
 
print(X41)
print(" ")
X42 = Card2.title()
 
print('Using The title Method')
 
print(X42)
print(" ")
X43 = Card2.translate("Faisal")
 
print('Using The translate Method')
 
print(X43)
print(" ")
X44 = Card2.upper()
 
print('Using The upper Method')
 
print(X44)

print(" ")
X45 = Card2.zfill(10)
 
print('Using The zfill Method')
 
print(X45)
# Out:
# Name: Muhammad Faisal Malik
# Institute Name : Saylani Mass IT Training
# Age: 23
#
# Using The capitalize Method
# Name: muhammad faisal malik
# institute name : saylani mass it training
# age: 23
#
# Using The casefold Method
# name: muhammad faisal malik
# institute name : saylani mass it training
# age: 23
#
# Using The center Method
# Name: Muhammad Faisal Malik
# Institute Name : Saylani Mass IT Training
# Age: 23
#
# Using The count Method
# 1
#
# Using The encode Method
# b'Name: Muhammad Faisal Malik  \nInstitute Name : Saylani Mass IT Training \nAge: 23'
#
# Using The endswith Method
# False
#
# Using The expandtabs Method
# Name: Muhammad Faisal Malik
# Institute Name : Saylani Mass IT Training
# Age: 23
#
# Using The find Method
# 15
#
# Using The format Method
# Name: Muhammad Faisal Malik
# Institute Name : Saylani Mass IT Training
# Age: 23
#
# Using The index Method
# 15
#
# Using The isalnum Method
# False
#
# Using The isalpha Method
# False
#
# ...
